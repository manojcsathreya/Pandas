# %% [markdown]
# <a href="https://colab.research.google.com/github/manojcsathreya/Pandas/blob/main/18_working_on_dataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
date=pd.date_range(
    start="2018",end="2019", freq="BM")

# %%
date
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31', '2018-06-29', '2018-07-31', '2018-08-31',
#                '2018-09-28', '2018-10-31', '2018-11-30', '2018-12-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
ts=pd.Series(
    np.random.randn(len(date)),index=date)
ts
# Out:
# 2018-01-31    0.661606
# 2018-02-28    0.716468
# 2018-03-30    0.244801
# 2018-04-30    0.279848
# 2018-05-31    1.341629
# 2018-06-29   -0.754668
# 2018-07-31    1.105209
# 2018-08-31   -0.428688
# 2018-09-28   -2.365892
# 2018-10-31   -0.037851
# 2018-11-30   -1.758639
# 2018-12-31   -0.170033
# Freq: BM, dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31', '2018-06-29', '2018-07-31', '2018-08-31',
#                '2018-09-28', '2018-10-31', '2018-11-30', '2018-12-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
ts[:5].index
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31'],
#               dtype='datetime64[ns]', freq='BM')

# %% [markdown]
# Reading a Time Series Data Set

# %%
fb = pd.read_csv('https://raw.githubusercontent.com/TirendazAcademy/PANDAS-TUTORIAL/main/DataSets/FB.csv')

# %%
fb.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 1  2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2  2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 3  2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 4  2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
#
#      Volume
# 0  65280800
# 1  40356500
# 2  34042100
# 3  32400000
# 4  24763400

# %%
fb.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
fb = pd.read_csv('https://raw.githubusercontent.com/TirendazAcademy/PANDAS-TUTORIAL/main/DataSets/FB.csv', parse_dates=['Date'])

# %%
fb
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 1   2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2   2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 3   2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 4   2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ..         ...         ...         ...         ...         ...         ...
# 246 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 247 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 248 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 249 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 250 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#        Volume
# 0    65280800
# 1    40356500
# 2    34042100
# ...

# %%
fb.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
fb = pd.read_csv('https://raw.githubusercontent.com/TirendazAcademy/PANDAS-TUTORIAL/main/DataSets/FB.csv', parse_dates=['Date'], index_col = 'Date')

# %%
fb
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ...                ...         ...         ...         ...         ...
# 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# ...

# %%
fb.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
fb.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# 2018-08-02  32400000
# 2018-08-03  24763400

# %%
fb['2018-09']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-09-04  173.500000  173.889999  168.800003  171.160004  171.160004
# 2018-09-05  169.490005  171.130005  166.669998  167.179993  167.179993
# 2018-09-06  166.979996  166.979996  160.000000  162.529999  162.529999
# 2018-09-07  160.309998  164.630005  160.160004  163.039993  163.039993
# 2018-09-10  163.509995  165.009995  162.160004  164.179993  164.179993
# 2018-09-11  163.940002  167.190002  163.720001  165.940002  165.940002
# 2018-09-12  163.250000  164.490005  161.800003  162.000000  162.000000
# 2018-09-13  162.000000  163.320007  160.860001  161.360001  161.360001
# ...

# %%
fb['2018-09'].Close.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# 164.37736842105267

# %%
fb["2019-07-05":"2019-07-10"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-07-05  196.179993  197.070007  194.169998  196.399994  196.399994
# 2019-07-08  195.190002  196.679993  193.639999  195.759995  195.759995
# 2019-07-09  194.970001  199.460007  194.889999  199.210007  199.210007
# 2019-07-10  200.000000  202.960007  199.669998  202.729996  202.729996
#
#               Volume
# Date
# 2019-07-05  11164100
# 2019-07-08   9723900
# 2019-07-09  14698600
# 2019-07-10  20571700

# %%
t=pd.to_datetime("7/22/2019")
t
# Out:
# Timestamp('2019-07-22 00:00:00')

# %%
fb.loc[fb.index>=t,:]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-07-22  199.910004  202.570007  198.809998  202.320007  202.320007
# 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#               Volume
# Date
# 2019-07-22  13589000
# 2019-07-23  14583700
# 2019-07-24  32532500
# 2019-07-25  39889900
# 2019-07-26  24426700
# 2019-07-29    754198

# %%
fb=pd.read_csv('https://raw.githubusercontent.com/TirendazAcademy/PANDAS-TUTORIAL/main/DataSets/FB-no-date.csv',sep=';')

# %%
fb
# Out:
#          Open       High        Low      Close  Adj Close    Volume
# 0   162600006  163130005  161690002  162279999  162279999  11097800
# 1   163899994  167500000  163830002  167369995  167369995  18894700
# 2   167369995  171880005  166550003  171259995  171259995  28187900
# 3   172899994  173570007  171270004  172509995  172509995  21531700
# 4   171500000  171740005  167610001  169130005  169130005  18306500
# 5   166199997  169619995  165970001  169600006  169600006  13184800
# 6   171600006  174300003  171580002  172070007  172070007  18884000
# 7   172089996  173800003  171220001  171919998  171919998  12155300
# 8   172320007  174029999  172119995  173369995  173369995  11973300
# 9   169759995  171149994  168160004  170169998  170169998  18037400
# 10  167160004  167580002  162509995  165979996  165979996  37135400
# 11  163570007  163899994  159279999  160470001  160470001  37524200
# 12  161479996  163820007  160820007  161570007  161570007  25611500
# ...

# %%
dates = pd.date_range('20200901','20200929',freq = 'B')

# %%
dates
# Out:
# DatetimeIndex(['2020-09-01', '2020-09-02', '2020-09-03', '2020-09-04',
#                '2020-09-07', '2020-09-08', '2020-09-09', '2020-09-10',
#                '2020-09-11', '2020-09-14', '2020-09-15', '2020-09-16',
#                '2020-09-17', '2020-09-18', '2020-09-21', '2020-09-22',
#                '2020-09-23', '2020-09-24', '2020-09-25', '2020-09-28',
#                '2020-09-29'],
#               dtype='datetime64[ns]', freq='B')

# %%
fb.set_index(dates, inplace=True)

# %%
fb
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2020-09-01  162600006  163130005  161690002  162279999  162279999  11097800
# 2020-09-02  163899994  167500000  163830002  167369995  167369995  18894700
# 2020-09-03  167369995  171880005  166550003  171259995  171259995  28187900
# 2020-09-04  172899994  173570007  171270004  172509995  172509995  21531700
# 2020-09-07  171500000  171740005  167610001  169130005  169130005  18306500
# 2020-09-08  166199997  169619995  165970001  169600006  169600006  13184800
# 2020-09-09  171600006  174300003  171580002  172070007  172070007  18884000
# 2020-09-10  172089996  173800003  171220001  171919998  171919998  12155300
# 2020-09-11  172320007  174029999  172119995  173369995  173369995  11973300
# 2020-09-14  169759995  171149994  168160004  170169998  170169998  18037400
# 2020-09-15  167160004  167580002  162509995  165979996  165979996  37135400
# ...

# %%
# %matplotlib inline

# %%
fb.Close.plot()

# %%
#the dataset consists of only business day data. What if we wnt to convertt that to calander days?
#we can use asfreq
fb.asfreq('H',method = 'pad')
# Out:
#                           Open       High        Low      Close  Adj Close  \
# 2020-09-01 00:00:00  162600006  163130005  161690002  162279999  162279999
# 2020-09-01 01:00:00  162600006  163130005  161690002  162279999  162279999
# 2020-09-01 02:00:00  162600006  163130005  161690002  162279999  162279999
# 2020-09-01 03:00:00  162600006  163130005  161690002  162279999  162279999
# 2020-09-01 04:00:00  162600006  163130005  161690002  162279999  162279999
# ...                        ...        ...        ...        ...        ...
# 2020-09-28 20:00:00  164570007  166720001  163330002  165550003  165550003
# 2020-09-28 21:00:00  164570007  166720001  163330002  165550003  165550003
# 2020-09-28 22:00:00  164570007  166720001  163330002  165550003  165550003
# 2020-09-28 23:00:00  164570007  166720001  163330002  165550003  165550003
# 2020-09-29 00:00:00  166389999  167190002  164809998  166690002  166690002
#
#                        Volume
# 2020-09-01 00:00:00  11097800
# ...

# %%
#values weekly
fb.asfreq('W',method ='pad')
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2020-09-06  172899994  173570007  171270004  172509995  172509995  21531700
# 2020-09-13  172320007  174029999  172119995  173369995  173369995  11973300
# 2020-09-20  161500000  166119995  161240005  165440002  165440002  20211500
# 2020-09-27  167850006  168940002  164789993  165869995  165869995  10620300
